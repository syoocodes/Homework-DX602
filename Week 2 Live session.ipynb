# %%
def mult_three(x):
    '''multiply the parameter x by 3'''
    return x*3

# %%
mult_three(14)
mult_three(5)

#see evaluation of last function call
# Out:
# 15

# %%
print('mult_three(14)=', mult_three(14))
#need to see which one is not working so you gotta write test statments in print
# Out:
# mult_three(14)= 42
